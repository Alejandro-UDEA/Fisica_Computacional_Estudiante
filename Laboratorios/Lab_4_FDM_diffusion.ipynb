# %% [markdown]
# # Lab 4: FDM-diffusion

# %% [markdown]
#  **Exercise** : Solve the diffusion equation for the next system.
#
# **Heat diffusion in a plate**
#
# Consider the diffusion equation applied to a metal plate initially at temperature $T_\text{cold}$
#
# Let's consider a rectangular heat-conducting plate with sides of lengths $a$ and $b$ with borders a temperature as is shown in figure. The flat faces are isolated, so they can't lose head to the surroundings.
#
# <img src="../Sesiones/PDE/figures/plato_coductor2.jpg" alt="Texto alternativo" width="400" height="400">
#
# 1. Solve the static solution of this system (Laplace's equation)
# 2. Found the temperature, i.e., solve the Diffusion equation for some times.
# 3. Do a gif for the Temperature.

# %%
pwd
# Out:
# '/home/usuario/Documentos/andres/Fisica_Computacional_1/Laboratorios'
